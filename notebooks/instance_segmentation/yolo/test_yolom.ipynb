# %%
from ultralytics import YOLO

# %%
DATA_PATH = r"E:\Education\4 course 2 semester\Diploma\panoptic_project\data\LaRS_fusion\instance_yolo\instance_yolo_dataset.yaml"

# %%
print("    BOX    ")
print(f"Precision:  0.725")
print(f"Recall:  0.411")
print(f"mAP50:  0.449")
print(f"mAP50-95:  0.281")

print("\n    SEG    ")
print(f"Precision:  0.649")
print(f"Recall:  0.337")
print(f"mAP50:  0.342")
print(f"mAP50-95:  0.169")
# Out:
#     BOX
# Precision:  0.725
# Recall:  0.411
# mAP50:  0.449
# mAP50-95:  0.281
#
#     SEG
# Precision:  0.649
# Recall:  0.337
# mAP50:  0.342
# mAP50-95:  0.169

# %%
print("    BOX    ")
print(f"mAP50:  0.1")
print(f"mAP50-95:  0.071")

print("\n    SEG    ")
print(f"mAP50:  0.118")
print(f"mAP50-95:  0.
# Out:
#     BOX
# mAP50:  0.172
# mAP50-95:  0.071
#
#     SEG
# mAP50:  0.118
# mAP50-95:  0.037

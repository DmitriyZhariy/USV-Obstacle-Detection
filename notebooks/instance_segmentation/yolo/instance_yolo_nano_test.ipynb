# %%
from ultralytics import YOLO

# %%
DATA_PATH = r"E:\Education\4 course 2 semester\Diploma\panoptic_project\data\LaRS_fusion\instance_yolo\instance_yolo_dataset.yaml"
MODEL_NAME = "yolo26n-seg.pt"

# %%
model = YOLO(r"E:\Education\4 course 2 semester\Diploma\panoptic_project\runs\instance_segmentation\yolo\yolo_nano_test\weights\best.pt")
metrics = model.val(
    data=DATA_PATH,
    project=r"E:\Education\4 course 2 semester\Diploma\panoptic_project\metrics\instance_segmentation\yolo\yolo_nan_test",
)

print("    BOX    ")
print(f"Precision: {metrics.box.mp:.3f}")
print(f"Recall: {metrics.box.mr:.3f}")
print(f"mAP50: {metrics.box.map50:.3f}")
print(f"mAP50-95: {metrics.box.map:.3f}")

print("\n    SEG    ")
print(f"Precision: {metrics.seg.mp:.3f}")
print(f"Recall: {metrics.seg.mr:.3f}")
print(f"mAP50: {metrics.seg.map50:.3f}")
print(f"mAP50-95: {metrics.seg.map:.3f}")
# Out:
# Ultralytics 8.4.26  Python-3.12.3 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1660 SUPER, 6144MiB)
# YOLO26n-seg summary (fused): 139 layers, 2,690,444 parameters, 0 gradients, 9.0 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 44.26.1 MB/s, size: 236.3 KB)
# val: Scanning E:\Education\4 course 2 semester\Diploma\panoptic_project\data\LaRS_fusion\instance_yolo\val\labels... 198 images, 38 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 198/198 377.7it/s 0.5s0.0s
# val: New cache created: E:\Education\4 course 2 semester\Diploma\panoptic_project\data\LaRS_fusion\instance_yolo\val\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.1s/it 14.4s0.3s
#                    all        198       1071      0.586      0.335      0.334      0.163       0.52      0.283      0.263      0.122
# ...
